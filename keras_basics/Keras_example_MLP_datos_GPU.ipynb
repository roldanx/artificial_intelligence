# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD

# Coger datos de MNIST

import tensorflow as tf
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(x_train.shape[0],x_train.shape[1]*x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1]*x_test.shape[2])

from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# Using TensorFlow backend.

# %%
# MODELO
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=784))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mean_squared_error',
              optimizer=sgd,
              metrics=['binary_accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# ENTRENAMIENTO CONTROLANDO EL TIEMPO

import timeit

start = timeit.default_timer()


model.fit(x_train, y_train,
          epochs=20,
          batch_size=128)

stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.1448 - binary_accuracy: 0.8546
# Epoch 2/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1263 - binary_accuracy: 0.8731
# Epoch 3/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0940 - binary_accuracy: 0.9055
# Epoch 4/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0795 - binary_accuracy: 0.9200
# Epoch 5/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0776 - binary_accuracy: 0.9220
# Epoch 6/20
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.0641 - binary_accuracy: 0.9356
# Epoch 7/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0442 - binary_accuracy: 0.9555
# Epoch 8/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0411 - binary_accuracy: 0.9586
# Epoch 9/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0399 - binary_accuracy: 0.9598
# Epoch 10/20
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0327 - binary_accuracy: 0.9671
# Epoch 11/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0218 - binary_accuracy: 0.9780
# Epoch 12/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0204 - binary_accuracy: 0.9794
# Epoch 13/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0198 - binary_accuracy: 0.9800
# Epoch 14/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0183 - binary_accuracy: 0.9815
# Epoch 15/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0186 - binary_accuracy: 0.9812
# Epoch 16/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0182 - binary_accuracy: 0.9816
# Epoch 17/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0173 - binary_accuracy: 0.9826
# Epoch 18/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0171 - binary_accuracy: 0.9827
# Epoch 19/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0164 - binary_accuracy: 0.9835
# Epoch 20/20
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.0168 - binary_accuracy: 0.9831
# Time:  34.670573778999824

# %%
# EVALUACION
score = model.evaluate(x_test, y_test, batch_size=128)

score
# Out:
# 10000/10000 [==============================] - 0s 16us/step
# [0.014167846062779427, 0.9857800003051758]

# %%
# COSAS DE LA GPU
# hay GPU?
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# QUE GPU?
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 6801614902438522993, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 1701692866394421235
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 3171244816938933547
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 10520746394
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 7089822591320766559
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]
