# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras import regularizers

# Coger datos de MNIST

import tensorflow as tf
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(x_train.shape[0],x_train.shape[1]*x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1]*x_test.shape[2])

from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
#aa = np.zeros(784,)
aa = np.ones(784,)
#aa[0] = 2

# MODELO
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=784))

model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mean_squared_error',
              optimizer=sgd,
              metrics=['binary_accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.fit(x_train, y_train,
          epochs=20,
          batch_size=128)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.1462 - binary_accuracy: 0.8533
# Epoch 2/20
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.1213 - binary_accuracy: 0.8781
# Epoch 3/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0991 - binary_accuracy: 0.9005
# Epoch 4/20
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0913 - binary_accuracy: 0.9084
# Epoch 5/20
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0912 - binary_accuracy: 0.9085
# Epoch 6/20
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0875 - binary_accuracy: 0.9122
# Epoch 7/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0770 - binary_accuracy: 0.9227
# Epoch 8/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0738 - binary_accuracy: 0.9259
# Epoch 9/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0724 - binary_accuracy: 0.9273
# Epoch 10/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0712 - binary_accuracy: 0.9286
# Epoch 11/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0709 - binary_accuracy: 0.9289
# Epoch 12/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0701 - binary_accuracy: 0.9297
# Epoch 13/20
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0702 - binary_accuracy: 0.9296
# Epoch 14/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0701 - binary_accuracy: 0.9297
# Epoch 15/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0706 - binary_accuracy: 0.9292
# Epoch 16/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0684 - binary_accuracy: 0.9314
# Epoch 17/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0697 - binary_accuracy: 0.9301
# Epoch 18/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0696 - binary_accuracy: 0.9302
# Epoch 19/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0694 - binary_accuracy: 0.9304
# Epoch 20/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0689 - binary_accuracy: 0.9309

# %%
# EVALUACION
score = model.evaluate(x_test, y_test, batch_size=128)

score
# Out:
# 10000/10000 [==============================] - 0s 16us/step
# [0.06837163108587264, 0.9314799877166748]
