# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD

# Coger datos de MNIST

import tensorflow as tf
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(x_train.shape[0],x_train.shape[1]*x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1]*x_test.shape[2])

from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
# MODELO
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=784))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mean_squared_error',
              optimizer=sgd,
              metrics=['binary_accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# ENTRENAMIENTO CONTROLANDO EL TIEMPO

import timeit

start = timeit.default_timer()


model.fit(x_train, y_train,
          epochs=20,
          batch_size=128)

stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1786 - binary_accuracy: 0.8213
# Epoch 2/20
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1478 - binary_accuracy: 0.8517
# Epoch 3/20
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1299 - binary_accuracy: 0.8697
# Epoch 4/20
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1153 - binary_accuracy: 0.8842
# Epoch 5/20
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1091 - binary_accuracy: 0.8904
# Epoch 6/20
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1086 - binary_accuracy: 0.8910
# Epoch 7/20
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.1073 - binary_accuracy: 0.8923
# Epoch 8/20
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1070 - binary_accuracy: 0.8926
# Epoch 9/20
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1066 - binary_accuracy: 0.8932
# Epoch 10/20
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.1064 - binary_accuracy: 0.8933
# Epoch 11/20
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.1058 - binary_accuracy: 0.8940
# Epoch 12/20
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.1057 - binary_accuracy: 0.8940
# Epoch 13/20
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.1062 - binary_accuracy: 0.8936
# Epoch 14/20
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.1060 - binary_accuracy: 0.8938
# Epoch 15/20
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.1049 - binary_accuracy: 0.8948
# Epoch 16/20
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.0939 - binary_accuracy: 0.9057
# Epoch 17/20
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.0805 - binary_accuracy: 0.9192
# Epoch 18/20
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.0756 - binary_accuracy: 0.9241
# Epoch 19/20
# 60000/60000 [==============================] - 1s 22us/step - loss: 0.0738 - binary_accuracy: 0.9259
# Epoch 20/20
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.0732 - binary_accuracy: 0.9265
# Time:  26.449736156000654

# %%
# EVALUACION
score = model.evaluate(x_test, y_test, batch_size=128)

score
# Out:
# 10000/10000 [==============================] - 0s 12us/step
# [0.07092667407989502, 0.9288800426483155]
