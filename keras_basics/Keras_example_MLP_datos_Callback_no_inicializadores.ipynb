# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD

# Coger datos de MNIST

import tensorflow as tf
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(x_train.shape[0],x_train.shape[1]*x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1]*x_test.shape[2])

from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
#aa = np.zeros(784,)
aa = np.ones(784,)
#aa[0] = 2

# MODELO
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=784))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mean_squared_error',
              optimizer=sgd,
              metrics=['binary_accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.fit(x_train, y_train,
          epochs=20,
          batch_size=128)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 60000/60000 [==============================] - 5s 81us/step - loss: 0.1597 - binary_accuracy: 0.8399
# Epoch 2/20
# 60000/60000 [==============================] - 3s 57us/step - loss: 0.1450 - binary_accuracy: 0.8547
# Epoch 3/20
# 60000/60000 [==============================] - 3s 57us/step - loss: 0.1413 - binary_accuracy: 0.8585
# Epoch 4/20
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.1261 - binary_accuracy: 0.8734
# Epoch 5/20
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.1006 - binary_accuracy: 0.8990
# Epoch 6/20
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0932 - binary_accuracy: 0.9065
# Epoch 7/20
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0915 - binary_accuracy: 0.9082
# Epoch 8/20
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.0897 - binary_accuracy: 0.9101
# Epoch 9/20
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0898 - binary_accuracy: 0.9100
# Epoch 10/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0889 - binary_accuracy: 0.9110
# Epoch 11/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0897 - binary_accuracy: 0.9102
# Epoch 12/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0891 - binary_accuracy: 0.9107
# Epoch 13/20
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0868 - binary_accuracy: 0.9129
# Epoch 14/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0774 - binary_accuracy: 0.9224
# Epoch 15/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0758 - binary_accuracy: 0.9240
# Epoch 16/20
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0740 - binary_accuracy: 0.9258
# Epoch 17/20
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0749 - binary_accuracy: 0.9249
# Epoch 18/20
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0731 - binary_accuracy: 0.9267
# Epoch 19/20
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0732 - binary_accuracy: 0.9267
# Epoch 20/20
# 60000/60000 [==============================] - 2s 27us/step - loss: 0.0730 - binary_accuracy: 0.9269

# %%
# EVALUACION
score = model.evaluate(x_test, y_test, batch_size=128)

score
# Out:
# 10000/10000 [==============================] - 0s 15us/step
# [0.07229121129512787, 0.9275999843597412]
