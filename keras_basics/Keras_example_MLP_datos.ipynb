# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD

# Coger datos de MNIST

import tensorflow as tf
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(x_train.shape[0],x_train.shape[1]*x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1]*x_test.shape[2])

from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# Using TensorFlow backend.

# %%
# MODELO
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=784))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# FUNCION DE COSTE, OPTIMIZADOR Y METRICA
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mean_squared_error',
              optimizer=sgd,
              metrics=['binary_accuracy'])

# ENTRENAMIENTO
model.fit(x_train, y_train,
          epochs=20,
          batch_size=128)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1333 - binary_accuracy: 0.8661
# Epoch 2/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.1004 - binary_accuracy: 0.8991
# Epoch 3/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0929 - binary_accuracy: 0.9068
# Epoch 4/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0882 - binary_accuracy: 0.9115
# Epoch 5/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0745 - binary_accuracy: 0.9252
# Epoch 6/20
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.0730 - binary_accuracy: 0.9268
# Epoch 7/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0720 - binary_accuracy: 0.9278
# Epoch 8/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0717 - binary_accuracy: 0.9281
# Epoch 9/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0702 - binary_accuracy: 0.9296
# Epoch 10/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0696 - binary_accuracy: 0.9301
# Epoch 11/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0670 - binary_accuracy: 0.9327
# Epoch 12/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0526 - binary_accuracy: 0.9472
# Epoch 13/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0409 - binary_accuracy: 0.9589
# Epoch 14/20
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.0379 - binary_accuracy: 0.9619
# Epoch 15/20
# 60000/60000 [==============================] - 1s 21us/step - loss: 0.0377 - binary_accuracy: 0.9621
# Epoch 16/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0358 - binary_accuracy: 0.9641
# Epoch 17/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0359 - binary_accuracy: 0.9639
# Epoch 18/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0350 - binary_accuracy: 0.9649
# Epoch 19/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0349 - binary_accuracy: 0.9649
# Epoch 20/20
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.0350 - binary_accuracy: 0.9649

# %%
#EVALUACIÓN
score = model.evaluate(x_test, y_test, batch_size=128)

score
# Out:
# 10000/10000 [==============================] - 0s 13us/step
# [0.03391575313806534, 0.9658400068283081]

# %%
# PREDICCIÓN
y_hat = model.predict(x_train)
