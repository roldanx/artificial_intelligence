# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras import regularizers

# Coger datos de MNIST

import tensorflow as tf
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(x_train.shape[0],x_train.shape[1]*x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1]*x_test.shape[2])

from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
#aa = np.zeros(784,)
aa = np.ones(784,)
#aa[0] = 2

# MODELO
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=784, 
                kernel_regularizer=regularizers.l2(0.1),
                activity_regularizer=regularizers.l1(0.1)))

model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mean_squared_error',
              optimizer=sgd,
              metrics=['binary_accuracy'])

# %%
model.fit(x_train, y_train,
          epochs=20,
          batch_size=128)
# Out:
# Epoch 1/20
# 60000/60000 [==============================] - 2s 36us/step - loss: 357273.1129 - binary_accuracy: 0.8998
# Epoch 2/20
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 3/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 4/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 5/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 6/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 7/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 8/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 9/20
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 10/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 11/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 12/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 13/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 14/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 15/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 16/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 17/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 18/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 19/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.0900 - binary_accuracy: 0.9000
# Epoch 20/20
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.0900 - binary_accuracy: 0.9000

# %%
# EVALUACION
score = model.evaluate(x_test, y_test, batch_size=128)

score
# Out:
# 10000/10000 [==============================] - 0s 14us/step
# [0.1483804194688797, 0.8516000866889953]
