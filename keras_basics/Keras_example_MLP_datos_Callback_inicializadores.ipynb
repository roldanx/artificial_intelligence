# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD

# Coger datos de MNIST

import tensorflow as tf
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(x_train.shape[0],x_train.shape[1]*x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1]*x_test.shape[2])

from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
import numpy as np
#aa = np.zeros(784,)
aa = np.ones(784,)
#aa[0] = 2

# MODELO
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=784, 
                bias_initializer = keras.initializers.Constant(value=0),
                kernel_initializer = keras.initializers.Constant(value=aa)))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mean_squared_error',
              optimizer=sgd,
              metrics=['binary_accuracy'])

# %%
model.fit(x_train, y_train,
          epochs=20,
          batch_size=128)
# Out:
# Epoch 1/20
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 2/20
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 3/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 4/20
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 5/20
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 6/20
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 7/20
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 8/20
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 9/20
# 60000/60000 [==============================] - 2s 32us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 10/20
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 11/20
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 12/20
# 60000/60000 [==============================] - 3s 57us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 13/20
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 14/20
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 15/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 16/20
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 17/20
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 18/20
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 19/20
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.1802 - binary_accuracy: 0.8198
# Epoch 20/20
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.1802 - binary_accuracy: 0.8198

# %%
# EVALUACION
score = model.evaluate(x_test, y_test, batch_size=128)

score
# Out:
# 10000/10000 [==============================] - 0s 42us/step
# [0.17982000560760497, 0.8201800216674805]
