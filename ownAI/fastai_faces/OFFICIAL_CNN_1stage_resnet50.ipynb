# %% [markdown]
# # Training

# %%
import pandas as pd
from fastai.vision.all import *
from fastai.metrics import accuracy, error_rate
from os import walk
from os.path import relpath
from pathlib import Path
from torch import cuda

# %%
cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Load data
# data can be downloaded from: https://www.kaggle.com/msambare/fer2013

# %%
# Images Path
root_path = Path('/home/roldanx/code/artificial_intelligence/ownAI/fastai_faces')
path_to_data = Path('/home/roldanx/code/artificial_intelligence/ownAI/fastai_faces/faces/train')

# Generate dataset
filelist = [relpath(os.path.join(dp, f), path_to_data) for dp, dn, filenames in os.walk(path_to_data) for f in filenames]
data_tuples = list(zip(filelist, [x.split("/")[0] for x in filelist]))
# .sample() randomizes dataframe order
df = pd.DataFrame(data_tuples, columns=['Path', 'Label']).sample(frac=1)
df
# Out:
#                                  Path     Label
# 11114     happy/Training_88289141.jpg     happy
# 28625  surprise/Training_95402552.jpg  surprise
# 22595   neutral/Training_40669152.jpg   neutral
# 16602      fear/Training_90135006.jpg      fear
# 21984    neutral/Training_2508608.jpg   neutral
# ...                               ...       ...
# 27597  surprise/Training_10746694.jpg  surprise
# 25676  surprise/Training_57032699.jpg  surprise
# 15090       sad/Training_98005812.jpg       sad
# 11537   disgust/Training_82817431.jpg   disgust
# 25226   neutral/Training_41893680.jpg   neutral
#
# [28709 rows x 2 columns]

# %% [markdown]
# ## Prepare data

# %%
dls = ImageDataLoaders.from_df(df, path_to_data, valid_pct=0.3, label_col=1, bs=64, item_tfms=Resize(192))
# dls = ImageDataLoaders.from_df(df, path_to_data, valid_pct=0.2, label_col=1, bs=64, val_bs=32, size=128, batch_tfms=Normalize.from_stats(*imagenet_stats))

# %%
# Original size
dls.train_ds[0][0].shape
# Out:
# (48, 48)

# %%
dls.show_batch()

# %% [markdown]
# ## Import CNN model

# %%
# Choose model
arch_model = models.resnet50

# %%
# Build TL model based on arch
learning_model = cnn_learner(dls, arch_model, metrics=[accuracy, error_rate])

# %%
# learning_model.model

# %%
# Labels counter
from collections import Counter
labels_count = Counter(label for label in df['Label'])
labels_count
# Out:
# Counter({'happy': 7215,
#          'surprise': 3171,
#          'neutral': 4965,
#          'fear': 4097,
#          'sad': 4830,
#          'angry': 3995,
#          'disgust': 436})

# %%
# Get Class Weights --> This will allow us to compensate the classes with less data
# total_count = sum(labels_count.values())
# class_weights = {cls: total_count / count for cls, count in labels_count.items()}
# class_weights

# class_weights = {'surprise':1.5, 'neutral':1, 'happy':1, 'angry':1.5, 'sad':1, 'fear':1.5, 'disgust':1.5}

# %%
# weights = [*class_weights.values()]
# class_weights=torch.FloatTensor(weights).cuda()
# learning_model.crit = nn.CrossEntropyLoss(weight=class_weights)

# %% [markdown]
# ## Training stage 1

# %%
# LR Finder helps to pick a good learning rate
learning_model.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# SuggestedLRs(lr_min=0.006918309628963471, lr_steep=7.585775847473997e-07)

# %%
# Train
learning_model.fit_one_cycle(6, 1e-02)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.452014</td>
#       <td>1.337739</td>
#       <td>0.508244</td>
#       <td>0.491756</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.263156</td>
#       <td>1.310780</td>
#       <td>0.507432</td>
#       <td>0.492569</td>
#       <td>03:41</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.135440</td>
#       <td>1.174743</td>
#       <td>0.572109</td>
#       <td>0.427891</td>
#       <td>03:41</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.038896</td>
#       <td>1.066507</td>
#       <td>0.591152</td>
#       <td>0.408848</td>
#       <td>03:41</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.880064</td>
#       <td>0.942802</td>
#       <td>0.648165</td>
#       <td>0.351835</td>
#       <td>03:41</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.729456</td>
#       <td>0.956551</td>
#       <td>0.649094</td>
#       <td>0.350906</td>
#       <td>03:41</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plot losses
learning_model.recorder.plot_loss()

# %%
# Save stage 1
# model_name = "resnet50_stage1_noNORM_184"
# learning_model.save(root_path / model_name)

# %% [markdown]
# ## Training stage 2

# %%
# Unfreeze
learning_model.unfreeze()

# Find LR
learning_model.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# SuggestedLRs(lr_min=9.12010818865383e-08, lr_steep=7.585775847473997e-07)

# %%
# Train
learning_model.fit_one_cycle(3, (slice(1e-6, 1e-4)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.720781</td>
#       <td>0.956620</td>
#       <td>0.653507</td>
#       <td>0.346493</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.654560</td>
#       <td>0.971855</td>
#       <td>0.655597</td>
#       <td>0.344403</td>
#       <td>04:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.552973</td>
#       <td>0.978174</td>
#       <td>0.655481</td>
#       <td>0.344519</td>
#       <td>04:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plot losses
learning_model.recorder.plot_loss()

# %%
# Save stage 2
# model_name = "resnet50_stage2_noNORM_184"
# learning_model.save(root_path / model_name)

# %%
# Remove ram stored data
del dls
del df

# %% [markdown]
# # Testing

# %%
# Images Path
path_to_test = Path('/home/roldanx/code/artificial_intelligence/ownAI/fastai_faces/faces/test')

# Generate dataset
filelist = [relpath(os.path.join(dp, f), path_to_test) for dp, dn, filenames in os.walk(path_to_test) for f in filenames]
data_tuples = list(zip(filelist, [x.split("/")[0] for x in filelist]))
df_test = pd.DataFrame(data_tuples, columns=['Path', 'Label'])
df_test
# Out:
#                                    Path     Label
# 0         angry/PublicTest_14075653.jpg     angry
# 1        angry/PrivateTest_73860110.jpg     angry
# 2         angry/PublicTest_18274972.jpg     angry
# 3         angry/PublicTest_14798104.jpg     angry
# 4         angry/PublicTest_51080774.jpg     angry
# ...                                 ...       ...
# 7173   surprise/PublicTest_17911043.jpg  surprise
# 7174   surprise/PublicTest_83231837.jpg  surprise
# 7175  surprise/PrivateTest_95778572.jpg  surprise
# 7176  surprise/PrivateTest_81533064.jpg  surprise
# 7177  surprise/PrivateTest_62895105.jpg  surprise
#
# [7178 rows x 2 columns]

# %%
# Generate test_dataloader
dls_test = ImageDataLoaders.from_df(df_test, path_to_test, label_col=1, bs=64, item_tfms=Resize(192))

# %%
# Switch train_dataloader to test_dataloader 
learning_model.dls = dls_test
arr = learning_model.validate()

# Switch test_dataloader to train_dataloader 
# learning_model.dls = dls

# %%
arr
# Out:
# (#3) [2.021794080734253,0.3442508578300476,0.6557491421699524]

# %%
interp = ClassificationInterpretation.from_learner(learning_model)
interp.plot_confusion_matrix(figsize=(8,8), dpi=60)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='23' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>

# %%
learning_model.show_results()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>

# %%
# learning_model.__dict__
